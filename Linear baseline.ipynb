# %%
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error
from csv import writer
def evaluate_linear(x_test, y_test, model):
    y_pred = model.predict(x_test)

    avg_abs_per_error = mean_absolute_percentage_error(y_test, y_pred)
    avg_abs_error = mean_absolute_error(y_test, y_pred)
    avg_mean_sq_error = root_mean_squared_error(y_test, y_pred)

    print(f"Mean absolute percentage error: {avg_abs_per_error}")
    print(f"Mean absolute error: {avg_abs_error}")
    print(f"Mean root mean squared error: {avg_mean_sq_error}")

    return np.array([avg_abs_per_error, avg_abs_error, avg_mean_sq_error])

path = str(Path.cwd())
files = ["AUFNIRA_z3.637557.smt2", "artificl.tar", "Johnny_1280x720_60_short.y4m", "ambivert.wav.tar", "smallbank-1", "jpeg-large", "corona", "beethoven.wav", "ambivert"]
for file in files:

    data = pd.read_csv(path + "/data sets/"+ file +".csv")
    print(f"Training for {file}")
    data_array = data.to_numpy()

    x = data_array[:,:-1]
    y = data_array[:,-1:]

    features =  x.shape[1]
    hidden = int(features * 7.5)
    batch = int(x.shape[0] / 50)
    rng = np.random.RandomState(seed=111111)
    repetitions = 1
    metrics = np.zeros((repetitions,3))
    for i in range(repetitions):
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
        model = LinearRegression().fit(x_train, y_train)
        print("Results on test set:")
        metrics[i] = evaluate_linear(x_test, y_test, model)
    with open(path + "/data analysis/" + file +" linear test_set analysis.csv", 'w', newline='') as file_object:
        writer_object = writer(file_object)
        for j  in range(metrics.shape[0]):
            writer_object.writerow(metrics[j])
# Out:
# Training for AUFNIRA_z3.637557.smt2
# Results on test set:
# Mean absolute percentage error: 7.212125467824746
# Mean absolute error: 87.70598427492789
# Mean root mean squared error: 99.6500852127757
# Results on test set:
# Mean absolute percentage error: 7.1712248290242036
# Mean absolute error: 88.98507107534036
# Mean root mean squared error: 100.31255997543532
# Results on test set:
# Mean absolute percentage error: 7.26240871353975
# Mean absolute error: 91.23552534790922
# Mean root mean squared error: 103.79579412876299
# Training for artificl.tar
# Results on test set:
# Mean absolute percentage error: 0.2771888404422336
# Mean absolute error: 0.006210428810119629
# Mean root mean squared error: 0.007362177654639514
# Results on test set:
# Mean absolute percentage error: 0.28370430416531034
# Mean absolute error: 0.006387519327799479
# Mean root mean squared error: 0.007539402721822576
# Results on test set:
# Mean absolute percentage error: 0.29276163313123915
# Mean absolute error: 0.006351664733886718
# Mean root mean squared error: 0.007575113244970886
# Training for Johnny_1280x720_60_short.y4m
# Results on test set:
# Mean absolute percentage error: 0.9758160951541466
# Mean absolute error: 2.606872873418284
# Mean root mean squared error: 3.3428289651531227
# Results on test set:
# Mean absolute percentage error: 0.878396241999291
# Mean absolute error: 2.5618362306767435
# Mean root mean squared error: 3.392968177415306
# Results on test set:
# Mean absolute percentage error: 0.985102407901803
# Mean absolute error: 2.570001607313439
# Mean root mean squared error: 3.3620187905556547
# Training for ambivert.wav.tar
# Results on test set:
# Mean absolute percentage error: 1.7368384170658728
# Mean absolute error: 12.859153533146507
# Mean root mean squared error: 18.654891472380573
# Results on test set:
# Mean absolute percentage error: 1.49927138550748
# Mean absolute error: 13.449084874715869
# Mean root mean squared error: 21.590327074290244
# Results on test set:
# Mean absolute percentage error: 1.790691121154846
# Mean absolute error: 13.818362068965518
# Mean root mean squared error: 21.049764158315163
# Training for smallbank-1
# Results on test set:
# Mean absolute percentage error: 0.055412368612629714
# Mean absolute error: 1081.5017154496743
# Mean root mean squared error: 1299.8966108786822
# Results on test set:
# Mean absolute percentage error: 0.05757151774041601
# Mean absolute error: 1126.3999585899005
# Mean root mean squared error: 1362.8645073162597
# Results on test set:
# Mean absolute percentage error: 0.05783873943862791
# Mean absolute error: 1124.7052312590235
# Mean root mean squared error: 1355.3684099776985
# Training for jpeg-large
# Results on test set:
# Mean absolute percentage error: 0.1343099379020303
# Mean absolute error: 0.41448380894416137
# Mean root mean squared error: 0.5605194826496134
# Results on test set:
# Mean absolute percentage error: 0.1361698442984542
# Mean absolute error: 0.4209499381737001
# Mean root mean squared error: 0.568273633087402
# Results on test set:
# Mean absolute percentage error: 0.13027426061606434
# Mean absolute error: 0.41392784629801554
# Mean root mean squared error: 0.5745265699515438
# Training for corona
# Results on test set:
# Mean absolute percentage error: 0.1298755971551191
# Mean absolute error: 0.1903744545970141
# Mean root mean squared error: 0.2680402382883339
# Results on test set:
# Mean absolute percentage error: 0.12298392945430946
# Mean absolute error: 0.17701756456599604
# Mean root mean squared error: 0.24858961849074318
# Results on test set:
# Mean absolute percentage error: 0.11987098151248217
# Mean absolute error: 0.1764637134876822
# Mean root mean squared error: 0.2540327903961642
# Training for beethoven.wav
# Results on test set:
# Mean absolute percentage error: 0.26472525708108513
# Mean absolute error: 2.276950899427785
# Mean root mean squared error: 2.90454514081017
# Results on test set:
# Mean absolute percentage error: 0.248472879978737
# Mean absolute error: 2.149530481824412
# Mean root mean squared error: 2.7891033226385766
# Results on test set:
# Mean absolute percentage error: 0.246144670545404
# Mean absolute error: 2.2576752449209847
# Mean root mean squared error: 2.9021044008123966
# Training for ambivert
# Results on test set:
# Mean absolute percentage error: 1.4334763238515347
# Mean absolute error: 18.308750613257008
# Mean root mean squared error: 29.27427590692112
# Results on test set:
# Mean absolute percentage error: 1.449709801088888
# Mean absolute error: 17.074154866607714
# Mean root mean squared error: 26.889319052568293
# Results on test set:
# Mean absolute percentage error: 1.4958466526136638
# Mean absolute error: 17.24081113607389
# Mean root mean squared error: 28.006586652288174
